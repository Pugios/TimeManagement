# %%
import json
from pprint import pprint

# %%
data = None

with open("/Users/matar/Documents/PugiosDocuments/OwnProjects/TimeManagement/data/Timeline.json", 'r') as file:
    data = json.load(file)

print(data.keys())
print(f"{len(data["rawSignals"])}, {data["rawSignals"][0]['activityRecord'].keys()}")
pprint(data["rawSignals"])
# print(json.dumps(data, indent=4))
# Out:
# dict_keys(['semanticSegments', 'rawSignals', 'userLocationProfile'])
# 3853, dict_keys(['probableActivities', 'timestamp'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       6 print(data.keys())
#       7 print(f"{len(data["rawSignals"])}, {data["rawSignals"][0]['activityRecord'].keys()}")
# ----> 8 pprint(data["rawSignals"]['activityRecord'])
#       9 # print(json.dumps(data, indent=4))
#
# TypeError: list indices must be integers or slices, not str
